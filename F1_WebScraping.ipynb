# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.formula1.com/en/results.html/2024/drivers.html'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', class_='f1-table f1-table-with-data w-full')
    rows = table.find_all('tr')
    data = []
    for row_id, row in enumerate(rows):
        columns = row.find_all('td')
        if columns:
            position = columns[0].text.strip()
            driver_name = columns[1].text.strip().split()
            driver_name = ' '.join(driver_name[:-1])
            nationality = columns[2].text.strip()
            car = columns[3].text.strip()
            pts = columns[4].text.strip()
            print(f"Position: {position}\
                    \nDriver Name: {driver_name}\
                    \nNationality: {nationality}\
                    \nCar: {car}\
                    \nPoints: {pts}\n\n")
            data.append({"Position": position, 
                         "Driver Name": driver_name, 
                         "Nationality": nationality,
                         "Car": car, "Points": pts })
    df = pd.DataFrame(data)
    df.to_csv("f1_drivers.csv", index = False, lineterminator="\n",  encoding = "utf-8-sig")
    print("Data is successfully saved into f1_drivers.csv")
else:
    print(f"Request unsuccesful, code: {response.status_code}")
# Out:
# Position: 1
# Driver Name: Max
# Nationality: NED
# Car: Red Bull Racing Honda RBPT
# Points: 331
#
#
# Position: 2
# Driver Name: Lando
# Nationality: GBR
# Car: McLaren Mercedes
# Points: 279
#
#
# Position: 3
# Driver Name: Charles
# Nationality: MON
# Car: Ferrari
# Points: 245
#
#
# Position: 4
# Driver Name: Oscar
# Nationality: AUS
# Car: McLaren Mercedes
# Points: 237
#
#
# Position: 5
# Driver Name: Carlos
# Nationality: ESP
# Car: Ferrari
# Points: 190
#
#
# Position: 6
# Driver Name: Lewis
# Nationality: GBR
# Car: Mercedes
# Points: 174
#
#
# Position: 7
# Driver Name: George
# Nationality: GBR
# Car: Mercedes
# Points: 155
#
#
# Position: 8
# Driver Name: Sergio
# Nationality: MEX
# Car: Red Bull Racing Honda RBPT
# Points: 144
#
#
# Position: 9
# Driver Name: Fernando
# Nationality: ESP
# Car: Aston Martin Aramco Mercedes
# Points: 62
#
#
# Position: 10
# Driver Name: Nico
# Nationality: GER
# Car: Haas Ferrari
# Points: 24
#
#
# Position: 11
# Driver Name: Lance
# Nationality: CAN
# Car: Aston Martin Aramco Mercedes
# Points: 24
#
#
# Position: 12
# Driver Name: Yuki
# Nationality: JPN
# Car: RB Honda RBPT
# Points: 22
#
#
# Position: 13
# Driver Name: Alexander
# Nationality: THA
# Car: Williams Mercedes
# Points: 12
#
#
# Position: 14
# Driver Name: Daniel
# Nationality: AUS
# Car: RB Honda RBPT
# Points: 12
#
#
# Position: 15
# Driver Name: Pierre
# Nationality: FRA
# Car: Alpine Renault
# Points: 8
#
#
# Position: 16
# Driver Name: Oliver
# Nationality: GBR
# Car: Haas Ferrari
# Points: 7
#
#
# Position: 17
# Driver Name: Kevin
# Nationality: DEN
# Car: Haas Ferrari
# Points: 6
#
#
# Position: 18
# Driver Name: Esteban
# Nationality: FRA
# Car: Alpine Renault
# Points: 5
#
#
# Position: 19
# Driver Name: Franco
# Nationality: ARG
# Car: Williams Mercedes
# Points: 4
#
#
# Position: 20
# Driver Name: Zhou
# Nationality: CHN
# Car: Kick Sauber Ferrari
# Points: 0
#
#
# Position: 21
# Driver Name: Logan
# Nationality: USA
# Car: Williams Mercedes
# Points: 0
#
#
# Position: 22
# Driver Name: Valtteri
# Nationality: FIN
# Car: Kick Sauber Ferrari
# Points: 0
#
#
# Data is successfully saved into f1_drivers.csv
